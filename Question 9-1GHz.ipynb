# %%
import os
import glob
from matplotlib import pyplot as plt

# %%
data = {}

for filename in glob.glob("./power_sim/pow/*1000MHz.log"):
    test, _ = os.path.splitext(filename.split("/")[-1])
    test = test.split("-")[1]
    with open(filename) as f:
        data[test] = f.readlines()

# %%
def find_line(file_content: [str], pattern: str) -> str:
    for line in file_content:
        if pattern in line:
            return line
    return ""

# %%
DPI=128

# Power consumption
for test in data.keys():
    print(find_line(data[test], "gpu_tot_max_power").strip())
    max_cons = float(find_line(data[test], "gpu_tot_max_power").strip().split("=")[1])
    min_cons = float(find_line(data[test], "gpu_tot_min_power").strip().split("=")[1])
    avg_cons = float(find_line(data[test], "gpu_tot_avg_power").strip().split("=")[1])
    plt.bar(["min", "avg", "max"], [min_cons, avg_cons, max_cons], color=['tab:green', 'tab:blue', 'tab:red'])
    plt.ylabel("Watt")
    plt.title(f"Power consumption for '{test}'")
    plt.savefig(f"./plots/power_sim/{test}-power-min-avg-max-1000MHz.png", dpi=DPI)
    plt.show()
# Out:
# gpu_tot_max_power = 172.402
# gpu_tot_max_power = 114.037
# gpu_tot_max_power = 34.0587

# %%
# Execution time
for test in data.keys():
    with open(f"./power_sim/stats/{test}_stat-1000MHz.txt") as f:
        lines = f.readlines()
    
    clock_cycles = int(find_line(lines, "gpu_tot_sim_cycle").split("=")[1])
    core_freq = float(find_line(lines, "gpgpu_clock_domains").split()[1].split(":")[0]) * 1e6  # clock is in MHz
    execution_time = clock_cycles/core_freq
    plt.bar(test, execution_time)
    print(test, execution_time)
    
plt.ylabel("seconds")
plt.title(f"Execution time of the three benchmarks")
plt.savefig(f"./plots/power_sim/execution_times-1000MHz.png", dpi=DPI)
plt.show()
# Out:
# hotspot3d 0.0002886
# bfs 5.432e-06
# lud 3.0288e-05

# %%
print(f"bfs  su : {1.7576666666666667e-05 / 5.432e-06}")
print(f"hs3d su : {0.0008189066666666666 / 0.0002886}")
print(f"lud  su : {9.883333333333333e-05 / 3.0288e-05}")
# Out:
# bfs  su : 3.235763377515955
# hs3d su : 2.837514437514437
# lud  su : 3.2631185067793624

# %%
# Energy consumption

# No care for performances
for test in data.keys():
    with open(f"./power_sim/stats/{test}_stat-1000MHz.txt") as f:
        lines = f.readlines()

    clock_cycles = int(find_line(lines, "gpu_tot_sim_cycle").split("=")[1])
    core_freq = float(find_line(lines, "gpgpu_clock_domains").split()[1].split(":")[0]) * 1e6  # clock is in MHz
    execution_time = clock_cycles/core_freq
    
    avg_cons = float(find_line(data[test], "gpu_tot_avg_power").strip().split("=")[1])
    joules = avg_cons * execution_time
    plt.bar(test, joules)

plt.ylabel("joules")
plt.title(f"Power consumption of the three benchmarks")
plt.savefig(f"./plots/power_sim/power_consumption-1000MHz.png", dpi=DPI)
plt.show()
